# %%
import preprocess
import pandas as pd

# %%
preprocess.load_clean_group().to_csv("crimes_group_word.csv")
# Out:
# Load successfully. The shape is
# (327820, 16)
# Clean successfully. The shape is
# (304659, 16)
# Group successfully

# %%
df = pd.read_csv("crimes_group_word.csv")

# %%
df.head(10)
# Out:
#   INCIDENT_NUMBER  OFFENSE_CODE               OFFENSE_CODE_GROUP  \
# 0      I182080058          2403               Disorderly Conduct
# 1      I182080053          3201                    Property Lost
# 2      I182080052          2647                            Other
# 3      I182080051           413               Aggravated Assault
# 4      I182080050          3122                         Aircraft
# 5      I182080049          1402                        Vandalism
# 6      I182080047          3301                  Verbal Disputes
# 7      I182080045           802                   Simple Assault
# 8      I182080044          3410                            Towed
# 9      I182080043          3803  Motor Vehicle Accident Response
#
#               OFFENSE_DESCRIPTION DISTRICT REPORTING_AREA SHOOTING  \
# 0            DISTURBING THE PEACE      E18            495        N
# 1                 PROPERTY - LOST      D14            795        N
# 2       THREATS TO DO BODILY HARM       B2            329        N
# 3  ASSAULT - AGGRAVATED - BATTERY       A1             92        N
# 4              AIRCRAFT INCIDENTS       A7             36        N
# 5                       VANDALISM      C11            351        N
# 6                  VERBAL DISPUTE       B2            603        N
# 7        ASSAULT SIMPLE - BATTERY      E18            543        N
# 8             TOWED MOTOR VEHICLE       D4            621        N
# 9  M/V ACCIDENT - PERSONAL INJURY      D14            750        N
#
#       OCCURRED_ON_DATE  YEAR  MONTH DAY_OF_WEEK  HOUR    UCR_PART  \
# 0  2018-10-03 20:13:00  2018     10   Wednesday    20    Part Two
# 1  2018-08-30 20:00:00  2018      8    Thursday    20  Part Three
# 2  2018-10-03 19:20:00  2018     10   Wednesday    19    Part Two
# 3  2018-10-03 20:00:00  2018     10   Wednesday    20    Part One
# 4  2018-10-03 20:49:00  2018     10   Wednesday    20  Part Three
# 5  2018-10-02 20:40:00  2018     10     Tuesday    20    Part Two
# 6  2018-10-03 19:32:00  2018     10   Wednesday    19  Part Three
# 7  2018-10-03 19:27:51  2018     10   Wednesday    19    Part Two
# 8  2018-10-03 20:00:00  2018     10   Wednesday    20  Part Three
# 9  2018-10-03 19:33:00  2018     10   Wednesday    19  Part Three
#
#              STREET        Lat       Long                     Location  \
# 0      ARLINGTON ST  42.262608 -71.121186  (42.26260773, -71.12118637)
# 1        ALLSTON ST  42.352111 -71.135311  (42.35211146, -71.13531147)
# 2          DEVON ST  42.308126 -71.076930  (42.30812619, -71.07692974)
# 3      CAMBRIDGE ST  42.359454 -71.059648  (42.35945371, -71.05964817)
# 4       PRESCOTT ST  42.375258 -71.024663  (42.37525782, -71.02466343)
# 5    DORCHESTER AVE  42.299197 -71.060470  (42.29919694, -71.06046974)
# 6        TREMONT ST  42.333807 -71.103778  (42.33380683, -71.10377843)
# 7          AVILA RD  42.256145 -71.128025  (42.25614494, -71.12802506)
# 8  COMMONWEALTH AVE  42.348866 -71.089363  (42.34886600, -71.08936284)
# 9         FOSTER ST  42.344323 -71.157784  (42.34432328, -71.15778368)
#
#    OFFENSE_GROUP                OFFENSE_DESCRIPTION_WORDS
# 0  Public Safety                  ['disturbing', 'peace']
# 1       Property                     ['property', 'lost']
# 2          Other            ['threats', 'bodily', 'harm']
# 3        Assault     ['assault', 'aggravated', 'battery']
# 4          Other                ['aircraft', 'incidents']
# 5       Property                            ['vandalism']
# 6        Dispute                    ['verbal', 'dispute']
# 7        Assault         ['assault', 'simple', 'battery']
# 8        Traffic            ['towed', 'motor', 'vehicle']
# 9        Traffic  ['v', 'accident', 'personal', 'injury']

# %%
df['OFFENSE_DESCRIPTION_WORDS'] = df['OFFENSE_DESCRIPTION_WORDS'].apply(ast.literal_eval)

# %%
l = ['a', 'b', 'b', 'c']
x=[]

for i in range(len(l) - 1):
    set_temp = set([l[i], l[i+1]])
    if len(set_temp) > 1:
        x.append(set_temp)

# %%
def get_bigram(word_list):
    tuple_list = [] 
    # to avoid "ValueError: all the input array dimensions
    # except for the concatenation axis must match exactly"
    
    if len(word_list) <= 1:
        return tuple_list
    
    for i in range(len(word_list) - 1):
        if len(word_list[i]) <= 3:
            continue
        for j in range(i + 1, len(word_list)):
            if len(word_list[j]) <= 3:
                continue
            set_temp = set([word_list[i], word_list[j]])
            if len(set_temp) > 1:
                tuple_list.append(str(tuple(set_temp)))

    return tuple_list

# %%
l = ['aaaaaa', 'bbbbbb', 'bbbbb', 'aa', 'caaaaa']
get_bigram(l)
# Out:
# ["('bbbbbb', 'aaaaaa')",
#  "('aaaaaa', 'bbbbb')",
#  "('caaaaa', 'aaaaaa')",
#  "('bbbbbb', 'bbbbb')",
#  "('caaaaa', 'bbbbbb')",
#  "('caaaaa', 'bbbbb')"]

# %%
df['bigram'] = df['OFFENSE_DESCRIPTION_WORDS'].apply(get_bigram)

# %%
bigram_list = np.hstack(list(df['bigram']))

# %%
from itertools import groupby
freq_dict = dict((k, len(list(xs))) for k, xs in groupby(sorted(bigram_list)))

# %%
freq_dict
# Out:
# {"('abandonment', 'assault')": 56,
#  "('abandonment', 'child')": 56,
#  "('abuse', 'animal')": 63,
#  "('accessories', 'larceny')": 1916,
#  "('accident', 'damage')": 5447,
#  "('accident', 'injury')": 6503,
#  "('accident', 'involving')": 2662,
#  "('accident', 'pedestrian')": 1651,
#  "('accident', 'personal')": 3841,
#  "('accident', 'police')": 626,
#  "('accident', 'vehicle')": 1222,
#  "('accidental', 'damage')": 880,
#  "('accidental', 'death')": 10,
#  "('accidental', 'firearm')": 10,
#  "('accostin', 'annoying')": 1,
#  "('accosting', 'annoying')": 116,
#  "('agency', 'another')": 185,
#  "('agency', 'investigation')": 185,
#  "('aircraft', 'incidents')": 31,
#  "('alarm', 'false')": 127,
#  "('alarm', 'fire')": 127,
#  "('alcohol', 'influence')": 404,
#  "('alcohol', 'operating')": 404,
#  "('animal', 'control')": 364,
#  "('animal', 'incidents')": 266,
#  "('annoyance', 'causing')": 25,
#  "('annoyance', 'gathering')": 25,
#  "('another', 'investigation')": 185,
#  "('arrest', 'order')": 1630,
#  "('arrest', 'radio')": 656,
#  "('assault', 'aggravated')": 7395,
#  "('assault', 'police')": 2,
#  "('assault', 'simple')": 15191,
#  "('assist', 'drug')": 322,
#  "('assist', 'drugs')": 1781,
#  "('assist', 'harmful')": 322,
#  "('assist', 'heroin')": 1150,
#  "('assist', 'narcotic')": 309,
#  "('assist', 'sick')": 1781,
#  "('assisting', 'prostitution')": 5,
#  "('attempt', 'bank')": 1,
#  "('attempt', 'burglary')": 825,
#  "('attempt', 'commerical')": 110,
#  "('attempt', 'force')": 1,
#  "('attempt', 'rescue')": 1,
#  "('attempt', 'residence')": 1,
#  "('attempt', 'residential')": 674,
#  "('attempt', 'robbery')": 1,
#  "('attempt', 'suicide')": 752,
#  "('attempted', 'enticing')": 44,
#  "('attempted', 'kidnapping')": 44,
#  "('attention', 'hands')": 1,
#  "('authorization', 'lawful')": 444,
#  "('authorization', 'operating')": 444,
#  "('auto', 'boston')": 1,
#  "('auto', 'lease')": 1,
#  "('auto', 'leased')": 368,
#  "('auto', 'motorcycle')": 829,
#  "('auto', 'outside')": 1,
#  "('auto', 'police')": 2,
#  "('auto', 'recovered')": 3,
#  "('auto', 'rent')": 1,
#  "('auto', 'rented')": 368,
#  "('auto', 'scooter')": 829,
#  "('auto', 'theft')": 4599,
#  "('auto', 'vehicle')": 369,
#  "('ballistics', 'evidence')": 961,
#  "('ballistics', 'found')": 961,
#  "('battery', 'aggravated')": 4610,
#  "('battery', 'assault')": 18870,
#  "('battery', 'police')": 1,
#  "('battery', 'simple')": 14244,
#  "('betting', 'wagering')": 8,
#  "('bicycle', 'accident')": 1011,
#  "('bicycle', 'injury')": 1056,
#  "('bicycle', 'involved')": 45,
#  "('bicycle', 'involving')": 1011,
#  "('bicycle', 'larceny')": 2233,
#  "('bicycle', 'theft')": 2230,
#  "('bites', 'animal')": 364,
#  "('bites', 'control')": 364,
#  "('bodily', 'threats')": 9083,
#  "('boston', 'outside')": 999,
#  "('boston', 'recovered')": 3997,
#  "('boston', 'stolen')": 1998,
#  "('brush', 'fire')": 487,
#  "('building', 'fire')": 1283,
#  "('burglarious', 'possession')": 211,
#  "('buying', 'possessing')": 912,
#  "('buying', 'stolen')": 912,
#  "('calls', 'phone')": 33,
#  "('carry', 'firearm')": 1,
#  "('carrying', 'firearm')": 810,
#  "('carrying', 'possessing')": 1372,
#  "('causing', 'gathering')": 25,
#  "('chain', 'store')": 1,
#  "('child', 'abuse')": 1,
#  "('child', 'assault')": 236,
#  "('city', 'accident')": 596,
#  "('city', 'construction')": 51,
#  "('city', 'ordinance')": 375,
#  "('city', 'permit')": 51,
#  "('city', 'vehicle')": 596,
#  "('city', 'violation')": 375,
#  "('class', 'disp')": 4190,
#  "('class', 'drugs')": 9680,
#  "('class', 'grams')": 284,
#  "('cocaine', 'class')": 2216,
#  "('cocaine', 'drugs')": 2216,
#  "('cocaine', 'poss')": 2216,
#  "('coin', 'machine')": 17,
#  "('commerical', 'burglary')": 1333,
#  "('common', 'nightwalker')": 12,
#  "('common', 'prostitute')": 1,
#  "('common', 'prostitution')": 11,
#  "('confiscated', 'firearm')": 675,
#  "('confiscated', 'found')": 675,
#  "('conspiracy', 'except')": 20,
#  "('construction', 'ordinance')": 51,
#  "('construction', 'permit')": 51,
#  "('construction', 'violation')": 51,
#  "('contributing', 'delinquency')": 8,
#  "('contributing', 'minor')": 8,
#  "('controlled', 'consp')": 75,
#  "('controlled', 'drugs')": 75,
#  "('counterfeiting', 'forgery')": 1458,
#  "('credit', 'card')": 3152,
#  "('credit', 'fraud')": 6304,
#  "('criminal', 'harassment')": 135,
#  "('custody', 'protective')": 28,
#  "('damage', 'leaving')": 14724,
#  "('dangerous', 'condition')": 289,
#  "('dangerous', 'firearm')": 3,
#  "('dangerous', 'hazardous')": 289,
#  "('dangerous', 'possession')": 3,
#  "('dangerous', 'weapon')": 3,
#  "('death', 'firearm')": 10,
#  "('death', 'sudden')": 1384,
#  "('demonstrations', 'riot')": 251,
#  "('depts', 'affecting')": 156,
#  "('disorderly', 'conduct')": 1282,
#  "('disorderly', 'person')": 1,
#  "('disp', 'drugs')": 4190,
#  "('dispute', 'verbal')": 13321,
#  "('dist', 'class')": 4190,
#  "('dist', 'disp')": 4190,
#  "('dist', 'drugs')": 4190,
#  "('dist', 'intent')": 4190,
#  "('dist', 'poss')": 4190,
#  "('drinking', 'liquor')": 768,
#  "('drinking', 'public')": 768,
#  "('drug', 'conspiracy')": 20,
#  "('drug', 'drugs')": 393,
#  "('drug', 'except')": 20,
#  "('drug', 'paraphanalia')": 71,
#  "('drug', 'possession')": 71,
#  "('drug', 'sick')": 322,
#  "('drugs', 'consp')": 75,
#  "('drugs', 'influence')": 66,
#  "('drugs', 'operating')": 66,
#  "('drugs', 'paraphanalia')": 71,
#  "('drugs', 'sale')": 1836,
#  "('endangerment', 'assault')": 180,
#  "('endangerment', 'child')": 432,
#  "('escape', 'recapture')": 18,
#  "('evidence', 'found')": 961,
#  "('explosives', 'found')": 11,
#  "('explosives', 'possession')": 13,
#  "('explosives', 'turned')": 11,
#  "('extortion', 'blackmail')": 190,
#  "('false', 'fire')": 127,
#  "('fare', 'evading')": 401,
#  "('feet', 'attention')": 1,
#  "('feet', 'hands')": 1,
#  "('felon', 'police')": 1,
#  "('force', 'burglary')": 6662,
#  "('force', 'commerical')": 1223,
#  "('force', 'residence')": 5,
#  "('force', 'residential')": 5020,
#  "('forcible', 'residence')": 2,
#  "('found', 'firearm')": 675,
#  "('found', 'turned')": 11,
#  "('fraud', 'card')": 6304,
#  "('fraud', 'false')": 4473,
#  "('fraud', 'pretense')": 4473,
#  "('fraud', 'welfare')": 14,
#  "('fraud', 'wire')": 332,
#  "('fugitive', 'justice')": 209,
#  "('gambling', 'betting')": 8,
#  "('gambling', 'wagering')": 8,
#  "('glue', 'drugs')": 1,
#  "('grams', 'drugs')": 284,
#  "('harm', 'bodily')": 9083,
#  "('harm', 'threats')": 9083,
#  "('harmful', 'drug')": 322,
#  "('harmful', 'drugs')": 322,
#  "('harmful', 'sick')": 322,
#  "('hazardous', 'condition')": 289,
#  "('heroin', 'class')": 1308,
#  "('heroin', 'drugs')": 2458,
#  "('heroin', 'sick')": 1150,
#  "('house', 'building')": 1283,
#  "('house', 'fire')": 1283,
#  "('impersonation', 'fraud')": 1061,
#  "('incident', 'harbor')": 102,
#  "('influence', 'operating')": 470,
#  "('inhalation', 'drugs')": 1,
#  "('inhalation', 'glue')": 1,
#  "('injured', 'medical')": 19707,
#  "('injured', 'person')": 18385,
#  "('injured', 'police')": 1322,
#  "('injured', 'sick')": 19707,
#  "('injury', 'accidental')": 10,
#  "('injury', 'death')": 10,
#  "('injury', 'firearm')": 10,
#  "('injury', 'involved')": 45,
#  "('injury', 'involving')": 2662,
#  "('injury', 'leaving')": 1038,
#  "('injury', 'pedestrian')": 1651,
#  "('injury', 'personal')": 4879,
#  "('inside', 'service')": 2428,
#  "('intent', 'class')": 4190,
#  "('intent', 'disp')": 4190,
#  "('intent', 'drugs')": 4190,
#  "('inticing', 'abduction')": 9,
#  "('invasion', 'home')": 106,
#  "('investigate', 'person')": 18379,
#  "('investigation', 'death')": 1177,
#  "('involving', 'pedestrian')": 1651,
#  "('jacking', 'robbery')": 76,
#  "('kidnapping', 'custodial')": 105,
#  "('kidnapping', 'enticing')": 44,
#  "('killing', 'felon')": 1,
#  "('killing', 'police')": 1,
#  "('knife', 'assault')": 2,
#  "('knife', 'attempt')": 1,
#  "('knife', 'bank')": 1,
#  "('knife', 'battery')": 1,
#  "('knife', 'officer')": 1,
#  "('knife', 'police')": 1,
#  "('knife', 'robbery')": 2,
#  "('knife', 'street')": 1,
#  "('landlord', 'service')": 999,
#  "('larceny', 'accessory')": 8574,
#  "('larceny', 'building')": 9124,
#  "('larceny', 'coin')": 17,
#  "('larceny', 'force')": 169,
#  "('larceny', 'machine')": 17,
#  "('larceny', 'pick')": 418,
#  "('lawful', 'operating')": 444,
#  "('lease', 'vehicle')": 1,
#  "('leased', 'concealing')": 26,
#  "('leased', 'rented')": 368,
#  "('leased', 'vehicle')": 368,
#  "('leaving', 'personal')": 1038,
#  "('license', 'operating')": 1623,
#  "('located', 'missing')": 5041,
#  "('located', 'person')": 5041,
#  "('lost', 'firearm')": 10,
#  "('lost', 'located')": 238,
#  "('lost', 'plates')": 488,
#  "('lost', 'weapon')": 10,
#  "('manslaughter', 'negligence')": 6,
#  "('manslaughter', 'negligient')": 152,
#  "('manslaughter', 'vehicle')": 6,
#  "('manufacturing', 'drugs')": 1836,
#  "('manufacturing', 'sale')": 1836,
#  "('marijuana', 'class')": 1,
#  "('marijuana', 'drugs')": 1,
#  "('marijuana', 'poss')": 1,
#  "('materials', 'obscene')": 85,
#  "('medical', 'person')": 18385,
#  "('medical', 'police')": 1322,
#  "('medical', 'sick')": 19707,
#  "('minor', 'delinquency')": 8,
#  "('missing', 'person')": 8800,
#  "('motor', 'towed')": 11061,
#  "('motor', 'vehicle')": 11061,
#  "('murder', 'manslaughter')": 152,
#  "('murder', 'negligient')": 152,
#  "('narcotic', 'drugs')": 309,
#  "('negligence', 'vehicle')": 6,
#  "('night', 'attempt')": 1,
#  "('night', 'force')": 2,
#  "('night', 'residence')": 2,
#  "('nightwalker', 'prostitute')": 1,
#  "('nightwalker', 'prostitution')": 11,
#  "('noisy', 'arrest')": 656,
#  "('noisy', 'party')": 656,
#  "('noisy', 'radio')": 656,
#  "('obscene', 'calls')": 33,
#  "('obscene', 'phone')": 33,
#  "('officer', 'assault')": 2,
#  "('officer', 'battery')": 1,
#  "('officer', 'police')": 5,
#  "('ordinance', 'permit')": 51,
#  "('others', 'larceny')": 5839,
#  "('outside', 'boston')": 1000,
#  "('outside', 'recovered')": 1999,
#  "('outside', 'service')": 189,
#  "('outside', 'stolen')": 999,
#  "('parts', 'accessories')": 1916,
#  "('parts', 'larceny')": 1916,
#  "('parts', 'theft')": 1916,
#  "('party', 'arrest')": 656,
#  "('party', 'radio')": 656,
#  "('peace', 'disturbing')": 789,
#  "('peddler', 'hawker')": 11,
#  "('plate', 'recovered')": 68,
#  "('pocket', 'larceny')": 418,
#  "('pocket', 'pick')": 418,
#  "('police', 'recovered')": 2,
#  "('police', 'vehicle')": 626,
#  "('pornography', 'materials')": 85,
#  "('pornography', 'obscene')": 85,
#  "('poss', 'class')": 9396,
#  "('poss', 'disp')": 4190,
#  "('poss', 'drugs')": 9396,
#  "('poss', 'heroin')": 1308,
#  "('poss', 'intent')": 4190,
#  "('possessing', 'firearm')": 810,
#  "('possession', 'drugs')": 238,
#  "('possession', 'firearm')": 3,
#  "('possession', 'paraphanalia')": 71,
#  "('premise', 'license')": 1685,
#  "('premise', 'violation')": 1685,
#  "('pretense', 'false')": 4473,
#  "('prisoner', 'attempt')": 23,
#  "('prisoner', 'escape')": 18,
#  "('prisoner', 'recapture')": 9,
#  "('prisoner', 'rescue')": 1,
#  "('prisoner', 'suicide')": 44,
#  "('promoting', 'assisting')": 5,
#  "('promoting', 'prostitution')": 5,
#  "('prop', 'residence')": 2,
#  "('prop', 'taken')": 2,
#  "('property', 'accident')": 5447,
#  "('property', 'accidental')": 880,
#  "('property', 'buying')": 912,
#  "('property', 'concealing')": 26,
#  "('property', 'damage')": 21051,
#  "('property', 'found')": 3514,
#  "('property', 'investigate')": 10893,
#  "('property', 'leased')": 26,
#  "('property', 'leaving')": 14724,
#  "('property', 'located')": 238,
#  "('property', 'lost')": 8983,
#  "('property', 'missing')": 884,
#  "('property', 'possessing')": 912,
#  "('property', 'receiving')": 914,
#  "('property', 'recovered')": 430,
#  "('property', 'stolen')": 1344,
#  "('public', 'liquor')": 768,
#  "('purse', 'force')": 169,
#  "('purse', 'larceny')": 169,
#  "('receiving', 'buying')": 912,
#  "('receiving', 'possessing')": 912,
#  "('receiving', 'stolen')": 914,
#  "('rent', 'carry')": 1,
#  "('rent', 'firearm')": 1,
#  "('rent', 'lease')": 1,
#  "('rent', 'vehicle')": 1,
#  "('report', 'affecting')": 156,
#  "('report', 'alarm')": 127,
#  "('report', 'brush')": 487,
#  "('report', 'building')": 1283,
#  "('report', 'depts')": 156,
#  "('report', 'false')": 127,
#  "('report', 'fire')": 1897,
#  "('report', 'house')": 1283,
#  "('reported', 'located')": 598,
#  "('reported', 'missing')": 598,
#  "('reported', 'person')": 598,
#  "('residential', 'burglary')": 5694,
#  "('restraining', 'arrest')": 1630,
#  "('restraining', 'order')": 1631,
#  "('robbery', 'bank')": 183,
#  "('robbery', 'chain')": 1,
#  "('robbery', 'commercial')": 566,
#  "('robbery', 'home')": 106,
#  "('robbery', 'invasion')": 106,
#  "('robbery', 'store')": 1,
#  "('robbery', 'street')": 2770,
#  "('runaway', 'truancy')": 29,
#  "('safekeeping', 'custody')": 28,
#  "('safekeeping', 'protective')": 28,
#  "('sale', 'firearm')": 14,
#  "('scene', 'damage')": 14724,
#  "('scene', 'injury')": 1038,
#  "('scene', 'leaving')": 15762,
#  "('scene', 'personal')": 1038,
#  "('scene', 'property')": 14724,
#  "('scheme', 'false')": 4472,
#  "('scheme', 'fraud')": 4472,
#  "('scheme', 'pretense')": 4472,
#  "('scooter', 'motorcycle')": 829,
#  "('sell', 'carry')": 1,
#  "('sell', 'firearm')": 1,
#  "('sell', 'rent')": 1,
#  "('sell', 'weapon')": 1,
#  "('shoplifting', 'larceny')": 7998,
#  "('sick', 'drugs')": 1781,
#  "('sick', 'narcotic')": 309,
#  "('sick', 'person')": 18385,
#  "('sick', 'police')": 1322,
#  "('snatch', 'force')": 169,
#  "('snatch', 'larceny')": 169,
#  "('snatch', 'purse')": 169,
#  "('soliciting', 'prostitution')": 156,
#  "('stolen', 'plate')": 68,
#  "('stolen', 'possessing')": 912,
#  "('stolen', 'recovered')": 2496,
#  "('substance', 'consp')": 75,
#  "('substance', 'controlled')": 75,
#  "('substance', 'drugs')": 75,
#  "('susp', 'operating')": 2145,
#  "('taken', 'residence')": 2,
#  "('tenant', 'landlord')": 999,
#  "('tenant', 'service')": 999,
#  "('theft', 'accessories')": 1916,
#  "('theft', 'accessory')": 8573,
#  "('theft', 'boston')": 1,
#  "('theft', 'building')": 9118,
#  "('theft', 'coin')": 17,
#  "('theft', 'larceny')": 21854,
#  "('theft', 'lease')": 1,
#  "('theft', 'leased')": 368,
#  "('theft', 'machine')": 17,
#  "('theft', 'motorcycle')": 829,
#  "('theft', 'outside')": 1,
#  "('theft', 'police')": 2,
#  "('theft', 'recovered')": 3,
#  "('theft', 'rent')": 1,
#  "('theft', 'rented')": 368,
#  "('theft', 'scooter')": 829,
#  "('theft', 'vehicle')": 369,
#  "('threat', 'bomb')": 72,
#  "('threats', 'biological')": 2,
#  "('tools', 'burglarious')": 211,
#  "('tools', 'possession')": 211,
#  "('towed', 'vehicle')": 11061,
#  "('trafficking', 'class')": 284,
#  "('trafficking', 'drugs')": 284,
#  "('trafficking', 'firearm')": 14,
#  "('trafficking', 'grams')": 284,
#  "('trafficking', 'sale')": 14,
#  "('unarmed', 'chain')": 1,
#  "('unarmed', 'robbery')": 4,
#  "('unarmed', 'store')": 1,
#  "('unarmed', 'street')": 3,
#  "('unins', 'operating')": 891,
#  "('unreg', 'operating')": 891,
#  "('unreg', 'unins')": 891,
#  "('uttering', 'forgery')": 2,
#  "('vehicle', 'rented')": 368,
#  "('viol', 'arrest')": 1630,
#  "('viol', 'consp')": 75,
#  "('viol', 'controlled')": 75,
#  "('viol', 'drugs')": 75,
#  "('viol', 'order')": 1630,
#  "('viol', 'restraining')": 1630,
#  "('viol', 'substance')": 75,
#  "('violation', 'auto')": 2503,
#  "('violation', 'firearm')": 221,
#  "('violation', 'harbor')": 102,
#  "('violation', 'hawker')": 11,
#  "('violation', 'incident')": 102,
#  "('violation', 'license')": 1685,
#  "('violation', 'liquor')": 253,
#  "('violation', 'order')": 1,
#  "('violation', 'ordinance')": 375,
#  "('violation', 'peddler')": 11,
#  "('violation', 'permit')": 51,
#  "('violation', 'restraining')": 1,
#  "('warrant', 'arrest')": 7682,
#  "('warrant', 'search')": 946,
#  "('weapon', 'accidental')": 10,
#  "('weapon', 'carry')": 1,
#  "('weapon', 'carrying')": 1372,
#  "('weapon', 'confiscated')": 675,
#  "('weapon', 'death')": 10,
#  "('weapon', 'firearm')": 1744,
#  "('weapon', 'found')": 675,
#  "('weapon', 'injury')": 10,
#  "('weapon', 'possessing')": 1372,
#  "('weapon', 'possession')": 3,
#  "('weapon', 'rent')": 1,
#  "('weapon', 'sale')": 14,
#  "('weapon', 'trafficking')": 14,
#  "('weapon', 'violation')": 359,
#  "('without', 'license')": 1623,
#  "('without', 'operating')": 1623,
#  "('witness', 'intimidating')": 310}

# %%
d3 = {k : v for k,v in freq_dict.items() if v > 500}

# %%
len(d3)
# Out:
# 205

# %%
plt.figure(figsize=(50,50))
plt.bar(range(len(d3)), list(d3.values()), align='center')
plt.xticks(range(len(d3)), list(d3.keys()), rotation=90)
# # for python 2.x:
# plt.bar(range(len(D)), D.values(), align='center')  # python 2.x
# plt.xticks(range(len(D)), D.keys())  # in python 2.x

 
plt.savefig('books_read.jpg')

# %%
import ast

df['OFFENSE_DESCRIPTION_WORDS'] = df['OFFENSE_DESCRIPTION_WORDS'].apply(ast.literal_eval)

# %%
import numpy as np
# np.asarray(list(df['OFFENSE_DESCRIPTION_WORDS']), dtype = np.void)
word_list = np.hstack(list(df['OFFENSE_DESCRIPTION_WORDS']))

# %%
word_list_clean = [w for w in word_list if len(w) > 1]

# %%
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator

# %%
import matplotlib.pyplot as plt

# %%
from itertools import groupby
freq_dict = dict((k, len(list(xs))) for k, xs in groupby(sorted(word_list_clean)))

# %%
# Start with one review:
text = word_list

# Create and generate a word cloud image:
wordcloud = WordCloud(width=1800, height=1200, background_color='white').fit_words(freq_dict)

wordcloud.to_file("test.png")

# Display the generated image:
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
from ast import literal_eval
from wordcloud import WordCloud, ImageColorGenerator
import matplotlib.pyplot as plt
from itertools import groupby


def save_wordcloud(df, name = 'test.png'):
    if type(df['OFFENSE_DESCRIPTION_WORDS'][0]) == str:
        word_list = np.hstack(list(df['OFFENSE_DESCRIPTION_WORDS'].apply(literal_eval)))
    else:
        word_list = np.hstack(list(df['OFFENSE_DESCRIPTION_WORDS']))
    word_list_clean = [w for w in word_list if len(w) > 3] #consider words less than 3 characters are not meaningful
    freq_dict = dict((k, len(list(xs))) for k, xs in groupby(sorted(word_list_clean)))
    
    wordcloud = WordCloud(width=1280, height=720, background_color='white').fit_words(freq_dict)
    wordcloud.to_file(name)

# %%
save_wordcloud(df, 'test3.png')
