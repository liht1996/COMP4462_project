# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("crime.csv", engine='python', parse_dates = ['OCCURRED_ON_DATE'], index_col = ['INCIDENT_NUMBER'])
print(df.shape)
df.head(10)
# Out:
# (327820, 16)
#                  OFFENSE_CODE               OFFENSE_CODE_GROUP  \
# INCIDENT_NUMBER
# I182080058               2403               Disorderly Conduct
# I182080053               3201                    Property Lost
# I182080052               2647                            Other
# I182080051                413               Aggravated Assault
# I182080050               3122                         Aircraft
# I182080049               1402                        Vandalism
# I182080048               3803  Motor Vehicle Accident Response
# I182080047               3301                  Verbal Disputes
# I182080045                802                   Simple Assault
# I182080044               3410                            Towed
#
#                             OFFENSE_DESCRIPTION DISTRICT REPORTING_AREA  \
# INCIDENT_NUMBER
# I182080058                 DISTURBING THE PEACE      E18            495
# I182080053                      PROPERTY - LOST      D14            795
# ...

# %% [markdown]
# ## Remove NAN

# %%
df.groupby('SHOOTING').count()
# Out:
#           OFFENSE_CODE  OFFENSE_CODE_GROUP  OFFENSE_DESCRIPTION  DISTRICT  \
# SHOOTING
# N               326765              326765               326765    324993
# Y                 1055                1055                 1055      1053
#
#           REPORTING_AREA  OCCURRED_ON_DATE    YEAR   MONTH  DAY_OF_WEEK  \
# SHOOTING
# N                 326765            326765  326765  326765       326765
# Y                   1055              1055    1055    1055         1055
#
#             HOUR  UCR_PART  STREET     Lat    Long  Location
# SHOOTING
# N         326765    326677  315812  306168  306168    326765
# Y           1055      1050    1031    1020    1020      1055

# %%
from copy import deepcopy
df_clean = deepcopy(df)

# %%
df_clean['SHOOTING'] = df_clean['SHOOTING'].fillna("N")
df_clean.groupby('SHOOTING').count()
# Out:
#           OFFENSE_CODE  OFFENSE_CODE_GROUP  OFFENSE_DESCRIPTION  DISTRICT  \
# SHOOTING
# N               326765              326765               326765    324993
# Y                 1055                1055                 1055      1053
#
#           REPORTING_AREA  OCCURRED_ON_DATE    YEAR   MONTH  DAY_OF_WEEK  \
# SHOOTING
# N                 326765            326765  326765  326765       326765
# Y                   1055              1055    1055    1055         1055
#
#             HOUR  UCR_PART  STREET     Lat    Long  Location
# SHOOTING
# N         326765    326677  315812  306168  306168    326765
# Y           1055      1050    1031    1020    1020      1055

# %%
df_clean = df_clean.dropna(axis = 0)

print(df_clean.shape)
# Out:
# (304659, 16)

# %% [markdown]
# ## Explore type

# %%
df_type = deepcopy(df_clean)
df_type_group = df_type.groupby('OFFENSE_CODE_GROUP')

# %% [markdown]
# ### Words
#
# Larceny: theft of personal property
#
# Towed: (of a motor vehicle or boat) pull (another vehicle or boat) along with a rope, chain, or tow bar
#
# Burglary: entry into a building illegally with intent to commit a crime, especially theft
#
# Embezzlement: theft or misappropriation of funds placed in one's trust or belonging to one's employer'
#
# Disorderly Conduct: unruly behavior constituting a minor offense
#
# Evading Fare: 逃票
#
# Arson: the criminal act of deliberately setting fire to property
#
# Manslaughter: the crime of killing a human being without malice aforethought, or otherwise in circumstances not
# amounting to murder
#
# Search Warrants: a legal document authorizing a police officer or other official to enter and search premises
#
# Bomb Hoax: 炸弹恶作剧
#
# Homicide: the deliberate and unlawful killing of one person by another; murder
#
# Prostitution: the practice or occupation of engaging in sexual activity with someone for payment

# %%
df_type_group_count = df_type_group.count().sort_values(by = 'OFFENSE_CODE', ascending = False)
df_type_group_count
# Out:
#                                   OFFENSE_CODE  OFFENSE_DESCRIPTION  DISTRICT  \
# OFFENSE_CODE_GROUP
# Motor Vehicle Accident Response          31186                31186     31186
# Larceny                                  25808                25808     25808
# Medical Assistance                       23041                23041     23041
# Investigate Person                       18379                18379     18379
# Other                                    17508                17508     17508
# Simple Assault                           15264                15264     15264
# Vandalism                                15234                15234     15234
# Drug Violation                           14829                14829     14829
# Verbal Disputes                          13321                13321     13321
# Towed                                    11061                11061     11061
# Investigate Property                     10893                10893     10893
# ...

# %%
print(df_type_group_count.index)
# Out:
# Index(['Motor Vehicle Accident Response', 'Larceny', 'Medical Assistance',
#        'Investigate Person', 'Other', 'Simple Assault', 'Vandalism',
#        'Drug Violation', 'Verbal Disputes', 'Towed', 'Investigate Property',
#        'Larceny From Motor Vehicle', 'Property Lost', 'Warrant Arrests',
#        'Aggravated Assault', 'Fraud', 'Residential Burglary', 'Violations',
#        'Missing Person Located', 'Auto Theft', 'Robbery', 'Harassment',
#        'Missing Person Reported', 'Property Found', 'Confidence Games',
#        'Police Service Incidents', 'Disorderly Conduct',
#        'Fire Related Reports', 'License Violation',
#        'Restraining Order Violations', 'Firearm Violations', 'Counterfeiting',
#        'Recovered Stolen Property', 'Commercial Burglary', 'Liquor Violation',
#        'Auto Theft Recovery', 'Landlord/Tenant Disputes', 'Ballistics',
#        'Search Warrants', 'Assembly or Gathering Violations',
#        'Property Related Damage', 'Firearm Discovery',
# ...

# %% [markdown]
# ### Thinking:
#
# 1. Too much type. Need to be filtered or grouped (e.g. All kinds of theft).
# 2. Some types may not be useful for us if we will make a navigation function (e.g. Fraud, Confidece games).
# 3. Some types may happen in certain areas (e.g. Aircraft, Harbor)
# 4. Some actions may have some relationships (e.g. Recovered Stolen Property and Larceny, Missing Person Located and Missing Person Reported,

# %% [markdown]
# ## Group
#
# Should be noticed:
# 1. Traffic: 'Motor Vehicle Accident Response', 'Towed',
# 2. Property: 'Larceny', 'Vandalism', 'Larceny From Motor Vehicle', 'Property Lost', 'Residential Burglary', 'Property Related Damage', 'Auto Theft', 'Robbery', 'Other Burglary', 'Burglary - No Property Taken'
# 3. Assault: 'Simple Assault', 'Aggravated Assault', 'Harassment', 'Offenses Against Child / Family', 'Criminal Harassment', 'Homicide', 'Manslaughter'
# 4. Dispute: 'Verbal Disputes', 'Landlord/Tenant Disputes'
# 5. Violations: 'Drug Violation', 'Firearm Violations', 'Violations', 'License Violation', 'Restraining Order Violations', 'Liquor Violation', 'Assembly or Gathering Violations',
# 6. Public Safety: 'Disorderly Conduct', 'Ballistics', 'Firearm Discovery', 'Arson', 'Explosives', 'Biological Threat'
#
# Not relative:
# 7. Public Affair: 'Medical Assistance', 'Warrant Arrests', 'Investigate Person', 'Investigate Property', 'Police Service Incidents', 'Fire Related Reports', 'Search Warrants', 'License Plate Related Incidents', 'Prisoner Related Incidents', 'Service'
# 8. Fraud: 'Fraud', 'Confidence Games', 'Counterfeiting', 'Commercial Burglary', 'Embezzlement'
# 9. Other: 'Other', 'Missing Person Located', 'Missing Person Reported', 'Property Found', 'Recovered Stolen Property', 'Auto Theft Recovery', 'Operating Under the Influence', 'Evading Fare', 'Prostitution', 'Harbor Related Incidents', 'Bomb Hoax', 'Phone Call Complaints', 'Aircraft', 'Gambling'

# %%
def add_group(offense):
    group_dict = {
        'Traffic': ['Motor Vehicle Accident Response', 'Towed'],
        'Property': ['Larceny', 'Vandalism', 'Larceny From Motor Vehicle', 'Property Lost', 
                     'Residential Burglary', 'Property Related Damage', 'Auto Theft', 
                     'Robbery', 'Other Burglary', 'Burglary - No Property Taken'],
        'Assault': ['Simple Assault', 'Aggravated Assault', 'Harassment', 'Offenses Against Child / Family', 
                    'Criminal Harassment', 'Homicide', 'Manslaughter'],
        'Dispute': ['Verbal Disputes', 'Landlord/Tenant Disputes'],
        'Violations': ['Drug Violation', 'Firearm Violations', 'Violations', 'License Violation', 
                       'Restraining Order Violations', 'Liquor Violation', 'Assembly or Gathering Violations'],
        'Public Safety': ['Disorderly Conduct', 'Ballistics', 'Firearm Discovery', 'Arson', 'Explosives',
                          'Biological Threat'],
        'Public Affair': ['Medical Assistance', 'Warrant Arrests', 'Investigate Person', 'Investigate Property', 
                          'Police Service Incidents', 'Fire Related Reports', 'Search Warrants', 
                          'License Plate Related Incidents', 'Prisoner Related Incidents', 'Service'],
        'Fraud': ['Fraud', 'Confidence Games', 'Counterfeiting', 'Commercial Burglary', 'Embezzlement'],
        'Other': ['Other', 'Missing Person Located', 'Missing Person Reported', 'Property Found', 
                  'Recovered Stolen Property', 'Auto Theft Recovery', 'Operating Under the Influence', 
                  'Evading Fare', 'Prostitution', 'Harbor Related Incidents', 'Bomb Hoax', 'Phone Call Complaints', 
                  'Aircraft', 'Gambling']}
    
    for key in group_dict.keys():
        if offense in group_dict[key]:
            return key
        
    return np.nan

# %%
df_clean['OFFENSE_GROUP'] = df_clean['OFFENSE_CODE_GROUP'].apply(return_group)
